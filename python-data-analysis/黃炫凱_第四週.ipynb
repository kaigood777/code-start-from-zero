# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact

# %%
a=['圭味','大干','多田','十塔','皮皮恰恰']
def f(x):
    print(x)
interact(f,x=np.random.choice(['圭味','大干','多田','十塔','皮皮恰恰']))
# Out:
# interactive(children=(Text(value='皮皮恰恰', description='x'), Output()), _dom_classes=('widget-interact',))
# <function __main__.f(x)>
