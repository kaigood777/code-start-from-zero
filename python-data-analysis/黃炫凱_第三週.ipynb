# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
grades=np.random.randint(0,101,(3,10,5))
weights=np.array([0.25,0.25,0.25,0.15,0.10])
np.dot(grades,weights)
# Out:
# array([[43.6 , 49.65, 66.5 , 51.55, 68.8 , 35.85, 29.75, 35.7 , 62.2 ,
#         74.95],
#        [54.55, 45.05, 34.35, 47.95, 29.15, 57.65, 54.3 , 40.75, 49.15,
#         63.95],
#        [48.2 , 48.05, 53.6 , 35.7 , 62.15, 59.05, 56.55, 70.85, 32.75,
#         60.55]])

# %%
grades
