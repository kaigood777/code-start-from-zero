# %% [markdown]
# 簡單運算

# %%
2*3
# Out:
# 6

# %%
2**3
# Out:
# 8

# %%
7/3
# Out:
# 2.3333333333333335

# %% [markdown]
# 魔術指令

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %% [markdown]
# 用(0,-2) (1,10) (2,3) (3,13) (4,5)畫圖

# %%
plot([-2,10,3,13,5])

# %% [markdown]
# 用平均值是0 標準差是1找亂數

# %%
randn(10)
# Out:
# array([-0.20901975,  1.4545378 , -2.16968041, -1.25575558, -1.20776122,
#         0.70015507,  2.20451107, -1.73618698, -1.73605399, -0.66629569])

# %%
plot(randn(10))

# %%
plot([-2,1,2.7,3.3],[3,-5,6,0])

# %% [markdown]
# 用markdown做筆記

# %% [markdown]
# # 大標題
# ## 次標題
# 內文在這裡

# %% [markdown]
# ## 分項說明
# * 1
# * 2
# * 3

# %% [markdown]
# ctrl M後再按一次M 可以直接進入markdown(Jupyter)

# %% [markdown]
# # 連結
# [隨便取名](網址)
# ex:
# [精誠中學](https://www.cchs.chc.edu.tw/)

# %% [markdown]
# ## 插入圖片
# ![名字](檔名) //要存在同一個資料夾

# %% [markdown]
# ## 打數學符號
# 有一個函數 $f(x)=x^3-2x^2+5$ ，我想給它積分(前後加$就能變漂亮)
# 語法:
# $$\int_a^b f(x)\, dx$$

# %% [markdown]
# 串列

# %%
L=[3,9,10,-3,5]
plot(L)

# %%
L=[3,5,46,21]
F=[1,2,4,1]
L+F # list相加 串列相連
# Out:
# [3, 5, 46, 21, 1, 2, 4, 1]

# %%
3*L #三個字串相連

# %% [markdown]
# # 字串

# %%
name='john'
print('hello, '+ name + '!') #字串相加
# Out:
# hello, john!

# %%
5*name
# Out:
# 'johnjohnjohnjohnjohn'

# %%
message='''嗨你好
歡迎
光臨。
'''
print(message)
# Out:
# 嗨你好
# 歡迎
# 光臨。

# %% [markdown]
# # 1-9 拍拍機器人

# %%
a=input('a=') #輸入會是字串，無法進行運算
float(a)*2.5
# Out:
# a=2.5
# 76.25

# %% [markdown]
# ##匯率換算

# %%
m=input('美金價格')
twd=float(m)*30.5
print('台幣'+str(twd)+'元')
# Out:
# 美金價格120
# 台幣3660.0元

# %% [markdown]
# ## 拍拍機器人

# %%
message=input('>>')
print('拍拍')

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
high=[28.6,31.3,32.9,35.9,35.1,36.9,37.4,37.8,36.1,34.8,31.1,29.5]
low=[11.9,13.7,12.1,15.2,17.9,22.3,24.8,25.1,19.8,19.9,16,11.6]
month=range(1,13)
plt.plot(month,high)
plt.plot(month,low)
